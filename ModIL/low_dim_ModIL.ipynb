# %%
from mc_estimation import *

# %%
def train_verification(config, dataset, env_string, experiments = 10):

    total_mean_rew = []
    total_std_rew = []

    for _ in range(experiments):
        dynamics_data = dataset
        training_epochs = 10
        
        #Model environment dynamics s' <- (s,a)
        dynamics_data.dynamics_init()
        cartpole_model = DynamicsModel(dynamics_data.X_size, dynamics_data.Y_size)
        train_dynamicsModel(cartpole_model, dynamics_data, epochs=training_epochs)
        
        #Model Markov Chain dynamics
        dynamics_data.mc_init()
        cartpole_expert_mc = DynamicsModel(dynamics_data.X_size, dynamics_data.Y_size)
        train_dynamicsModel(cartpole_expert_mc, dynamics_data, epochs=training_epochs)

        print("Number of observations trained on: " + str(dynamics_data.num_observations))

        #Initialize Policy
        policy = Policy(dynamics_data.X_size, np.array([config["action_size"]]))
        print(dynamics_data.X.shape)
        print(dynamics_data.X_size)

        #Train Agent
        mc = mcEstimator(config=config, mc_model=cartpole_expert_mc, dynamics_model=cartpole_model, policy=policy, dataset=dynamics_data)
        mc.train_mc(mc.dataset.X)

        '''Test Performance of Agent'''
        env = gym.make(env_string)
        observation = env.reset()
        reward_total = 0
        reward_history = []
        steps = 0
        for _ in range(1000):
            # env.render()
            # action = env.action_space.sample() # your agent here (this takes random actions)
            
            observation = np.array([observation])
            # print(observation)
            observation = dynamics_data.transform_obs_forward(observation)
            # print(observation)
            # print()
            action_choices = policy(observation)
            # print(action_choices)
            action = np.argmax(action_choices)
            steps += 1
            # print("Action taken: " + str(action))
            observation, reward, done, info = env.step(action)
            reward_total += reward

            if done:
                observation = env.reset()
                print("Reward Total: " + str(reward_total))
                print("Reset")
                print("steps: " + str(steps))
                reward_history.append(reward_total)
                reward_total=0
                steps = 0
        
        print(np.mean(reward_history))
        print(np.std(reward_history))
        total_mean_rew.append(np.mean(reward_history))
        total_std_rew.append(np.std(reward_history))

        env.close()

    print("Mean reward over " + str(experiments) + " experiments: " + str(np.mean(total_mean_rew)))
    print("Mean std over " + str(experiments) + " experiments: " + str(np.std(total_mean_rew)))

# %%
import gym

env_string = "CartPole-v1"
action_size = 2
# env_string = "MountainCar-v0"
# action_Size = 3

config = {  
        "loss": tf.keras.losses.KLD, 
        "optimizer": tf.keras.optimizers.Adam(learning_rate=0.00001),
        "validation_split": 0.10,
        "max_obs": int(1e5),
        "epochs": 16,
        "batch_size": 64,
        "state_size": 2, 
        "action_size": action_size
            }

#Import dataset
dynamics_data = dc.dataset("cartpole10000.npz", max_obs=config["max_obs"])
# dynamics_data = dc.dataset("MountainCarDiscrete1000.npz", max_obs=config["max_obs"])

train_verification(config=config, dataset=dynamics_data, env_string=env_string)
# Out:
# ==] - 1s 1ms/step - loss: 0.0086 - mae: 0.0055 - acc: 0.9970 - val_loss: 0.0055 - val_mae: 0.0053 - val_acc: 0.9970
# Epoch 5/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0048 - mae: 0.0052 - acc: 0.9973 - val_loss: 0.0033 - val_mae: 0.0052 - val_acc: 0.9964
# Epoch 6/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0030 - mae: 0.0052 - acc: 0.9971 - val_loss: 0.0024 - val_mae: 0.0049 - val_acc: 0.9983
# Epoch 7/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0023 - mae: 0.0051 - acc: 0.9973 - val_loss: 0.0022 - val_mae: 0.0049 - val_acc: 0.9978
# Epoch 8/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0021 - mae: 0.0050 - acc: 0.9973 - val_loss: 0.0021 - val_mae: 0.0048 - val_acc: 0.9978
# Epoch 9/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0020 - mae: 0.0048 - acc: 0.9978 - val_loss: 0.0020 - val_mae: 0.0045 - val_acc: 0.9974
# Epoch 10/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0020 - mae: 0.0046 - acc: 0.9975 - val_loss: 0.0019 - val_mae: 0.0045 - val_acc: 0.9985
# [     0. 100000.]
# Epoch 1/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.2471 - mae: 0.3040 - acc: 0.7986 - val_loss: 0.0839 - val_mae: 0.1511 - val_acc: 0.8850
# Epoch 2/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0813 - mae: 0.1458 - acc: 0.8916 - val_loss: 0.0720 - val_mae: 0.1320 - val_acc: 0.9049
# Epoch 3/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0704 - mae: 0.1289 - acc: 0.9077 - val_loss: 0.0642 - val_mae: 0.1195 - val_acc: 0.9142
# Epoch 4/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0629 - mae: 0.1187 - acc: 0.9139 - val_loss: 0.0580 - val_mae: 0.1114 - val_acc: 0.9148
# Epoch 5/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0572 - mae: 0.1109 - acc: 0.9180 - val_loss: 0.0544 - val_mae: 0.1074 - val_acc: 0.9220
# Epoch 6/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0532 - mae: 0.1057 - acc: 0.9217 - val_loss: 0.0502 - val_mae: 0.1028 - val_acc: 0.9217
# Epoch 7/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0503 - mae: 0.1021 - acc: 0.9243 - val_loss: 0.0483 - val_mae: 0.0996 - val_acc: 0.9211
# Epoch 8/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0484 - mae: 0.0993 - acc: 0.9253 - val_loss: 0.0459 - val_mae: 0.0962 - val_acc: 0.9244
# Epoch 9/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0462 - mae: 0.0966 - acc: 0.9249 - val_loss: 0.0445 - val_mae: 0.0953 - val_acc: 0.9245
# Epoch 10/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0446 - mae: 0.0943 - acc: 0.9268 - val_loss: 0.0434 - val_mae: 0.0927 - val_acc: 0.9259
# Number of observations trained on: 100000
# (99806, 4)
# (4,)
# Epoch 0 Training Loss: 0.05882313
# Epoch 1 Training Loss: 0.045353424
# Epoch 2 Training Loss: 0.038969073
# Epoch 3 Training Loss: 0.034621984
# Epoch 4 Training Loss: 0.031451706
# Epoch 5 Training Loss: 0.02900707
# Epoch 6 Training Loss: 0.027027912
# Epoch 7 Training Loss: 0.02537023
# Epoch 8 Training Loss: 0.023949387
# Epoch 9 Training Loss: 0.022710444
# Epoch 10 Training Loss: 0.021620765
# Epoch 11 Training Loss: 0.020654807
# Epoch 12 Training Loss: 0.019790523
# Epoch 13 Training Loss: 0.019012038
# Epoch 14 Training Loss: 0.018306417
# Epoch 15 Training Loss: 0.017664153
# Reward Total: 500.0
# Reset
# steps: 500
# Reward Total: 500.0
# Reset
# steps: 500
# 500.0
# 0.0
# rewards
# 499.0
# 0.0
# 199
# 100000
# [     0. 100000.]
# Epoch 1/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.1881 - mae: 0.2003 - acc: 0.8949 - val_loss: 0.0230 - val_mae: 0.0106 - val_acc: 0.9957
# Epoch 2/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.
10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0800 - mae: 0.1439 - acc: 0.8920 - val_loss: 0.0703 - val_mae: 0.1278 - val_acc: 0.9114
# Epoch 3/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0690 - mae: 0.1268 - acc: 0.9091 - val_loss: 0.0627 - val_mae: 0.1163 - val_acc: 0.9191
# Epoch 4/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0617 - mae: 0.1163 - acc: 0.9153 - val_loss: 0.0585 - val_mae: 0.1152 - val_acc: 0.9194
# Epoch 5/10
# 1404/1404 [==============================] - 1s 974us/step - loss: 0.0566 - mae: 0.1099 - acc: 0.9188 - val_loss: 0.0536 - val_mae: 0.1061 - val_acc: 0.9235
# Epoch 6/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0527 - mae: 0.1048 - acc: 0.9219 - val_loss: 0.0501 - val_mae: 0.1005 - val_acc: 0.9277
# Epoch 7/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0500 - mae: 0.1012 - acc: 0.9237 - val_loss: 0.0483 - val_mae: 0.0992 - val_acc: 0.9309
# Epoch 8/10
# 1404/1404 [==============================] - 1s 992us/step - loss: 0.0476 - mae: 0.0981 - acc: 0.9246 - val_loss: 0.0462 - val_mae: 0.0963 - val_acc: 0.9275
# Epoch 9/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0461 - mae: 0.0965 - acc: 0.9265 - val_loss: 0.0446 - val_mae: 0.0941 - val_acc: 0.9285
# Epoch 10/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0446 - mae: 0.0943 - acc: 0.9268 - val_loss: 0.0431 - val_mae: 0.0914 - val_acc: 0.9307
# Number of observations trained on: 100000
# (99806, 4)
# (4,)
# Epoch 0 Training Loss: 0.058935564
# Epoch 1 Training Loss: 0.046055514
# Epoch 2 Training Loss: 0.03944489
# Epoch 3 Training Loss: 0.034828026
# Epoch 4 Training Loss: 0.031433325
# Epoch 5 Training Loss: 0.028834183
# Epoch 6 Training Loss: 0.026757846
# Epoch 7 Training Loss: 0.025040131
# Epoch 8 Training Loss: 0.023586247
# Epoch 9 Training Loss: 0.02232836
# Epoch 10 Training Loss: 0.021227438
# Epoch 11 Training Loss: 0.020255579
# Epoch 12 Training Loss: 0.019391356
# Epoch 13 Training Loss: 0.01861762
# Epoch 14 Training Loss: 0.017921913
# Epoch 15 Training Loss: 0.01729295
# Reward Total: 500.0
# Reset
# steps: 500
# Reward Total: 500.0
# Reset
# steps: 500
# 500.0
# 0.0
# rewards
# 499.0
# 0.0
# 199
# 100000
# [     0. 100000.]
# Epoch 1/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.1654 - mae: 0.1818 - acc: 0.9165 - val_loss: 0.0226 - val_mae: 0.0106 - val_acc: 0.9940
# Epoch 2/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0208 - mae: 0.0091 - acc: 0.9945 - val_loss: 0.0155 - val_mae: 0.0067 - val_acc: 0.9954
# Epoch 3/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0139 - mae: 0.0062 - acc: 0.9960 - val_loss: 0.0094 - val_mae: 0.0054 - val_acc: 0.9961
# Epoch 4/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0082 - mae: 0.0052 - acc: 0.9968 - val_loss: 0.0053 - val_mae: 0.0052 - val_acc: 0.9968
# Epoch 5/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0046 - mae: 0.0050 - acc: 0.9975 - val_loss: 0.0032 - val_mae: 0.0055 - val_acc: 0.9978
# Epoch 6/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0029 - mae: 0.0050 - acc: 0.9975 - val_loss: 0.0024 - val_mae: 0.0049 - val_acc: 0.9978
# Epoch 7/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0023 - mae: 0.0049 - acc: 0.9973 - val_loss: 0.0021 - val_mae: 0.0049 - val_acc: 0.9978
# Epoch 8/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0021 - mae: 0.0048 - acc: 0.9974 - val_loss: 0.0020 - val_mae: 0.0047 - val_acc: 0.9980
# Epoch 9/10
# 1404/1404 [==============================] - 1s 960us/step - loss: 0.0020 - mae: 0.0046 - acc: 0.9973 - val_loss: 0.0020 - val_mae: 0.0048 - val_acc: 0.9974
# Epoch 10/10
# 1404/1404 [==============================] - 1s 943us/step - loss: 0.0020 - mae: 0.0044 - acc: 0.9978 - val_loss: 0.0019 - val_mae: 0.0047 - val_acc: 0.9973
# [     0. 100000.]
# Epoch 1/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.2494 - mae: 0.3080 - acc: 0.7950 - val_loss: 0.0853 - val_mae: 0.1522 - val_acc: 0.8924
# Epoch 2/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0815 - mae: 0.1464 - acc: 0.8930 - val_loss: 0.0731 - val_mae: 0.1329 - val_acc: 0.9035
# Epoch 3/10
# 1404/1404 [==============================] - 1s 987us/step - loss: 0.0705 - mae: 0.1301 - acc: 0.9052 - val_loss: 0.0650 - val_mae: 0.1220 - val_acc: 0.9107
# Epoch 4/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0635 - mae: 0.1204 - acc: 0.9112 - val_loss: 0.0589 - val_mae: 0.1137 - val_acc: 0.9167
# Epoch 5/10
# 1404/1404 [==============================] - 2s 1ms/step - loss: 0.0583 - mae: 0.1137 - acc: 0.9165 - val_loss: 0.0554 - val_mae: 0.1110 - val_acc: 0.9225
# Epoch 6/10
# 1404/1404 [==============================] - 1s 951us/step - loss: 0.0543 - mae: 0.1088 - acc: 0.9198 - val_loss: 0.0523 - val_mae: 0.1061 - val_acc: 0.9242
# Epoch 7/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0514 - mae: 0.1048 - acc: 0.9235 - val_loss: 0.0493 - val_mae: 0.1028 - val_acc: 0.9234
# Epoch 8/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0492 - mae: 0.1022 - acc: 0.9243 - val_loss: 0.0470 - val_mae: 0.0980 - val_acc: 0.9283
# Epoch 9/10
# 1404/1404 [==============================] - 1s 980us/step - loss: 0.0469 - mae: 0.0988 - acc: 0.9238 - val_loss: 0.0456 - val_mae: 0.0960 - val_acc: 0.9247
# Epoch 10/10
# 1404/1404 [==============================] - 1s 1ms/step - loss: 0.0449 - mae: 0.0962 - acc: 0.9234 - val_loss: 0.0448 - val_mae: 0.0983 - val_acc: 0.9222
# Number of observations trained on: 100000
# (99806, 4)
# (4,)
# Epoch 0 Training Loss: 0.058774885
# Epoch 1 Training Loss: 0.0455385
# Epoch 2 Training Loss: 0.038953133
# Epoch 3 Training Loss: 0.03436122
# Epoch 4 Training Loss: 0.031036649
# Epoch 5 Training Loss: 0.02848543
# Epoch 6 Training Loss: 0.026450047
# Epoch 7 Training Loss: 0.024778564
# Epoch 8 Training Loss: 0.023368182
# Epoch 9 Training Loss: 0.022153107
# Epoch 10 Training Loss: 0.021094214
# Epoch 11 Training Loss: 0.020158852
# Epoch 12 Training Loss: 0.019325297
# Epoch 13 Training Loss: 0.01857947
# Epoch 14 Training Loss: 0.017908128
# Epoch 15 Training Loss: 0.017302115
# Reward Total: 500.0
# Reset
# steps: 500
# Reward Total: 500.0
# Reset
# steps: 500
# 500.0
# 0.0
# Mean reward over 10 experiments: 479.25
# Mean std over 10 experiments: 41.86003463925944
